# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.compat.v1.losses import sparse_softmax_cross_entropy
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\AML-manyahegde\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load data from intents.json
with open('intents.json') as file:
    data = json.load(file)

# %%
data
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'Hey', 'Is anyone there?', 'Hello', 'Hay'],
#    'responses': ['Hello', 'Hi', 'Hi there']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye', 'See you later', 'Goodbye'],
#    'responses': ['See you later', 'Have a nice day', 'Bye! Come back again']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Thanks for the help'],
#    'responses': ['Happy to help!',
#     'Any time!',
#     'My pleasure',
#     "You're most welcome!"]},
#   {'tag': 'about',
#    'patterns': ['Who are you?', 'What are you?', 'Who you are?'],
#    'responses': ['I.m Joana, your bot assistant',
#     "I'm Joana, an Artificial Intelligent bot"]},
#   {'tag': 'name',
#    'patterns': ['what is your name',
#     'what should I call you',
#     'whats your name?'],
#    'responses': ['You can call me Joana.',
#     "I'm Joana!",
#     'Just call me as Joana']},
#   {'tag': 'help',
#    'patterns': ['Could you help me?',
#     'give me a hand please',
#     'Can you help?',
#     'What can you do for me?',
#     'I need a support',
#     'I need a help',
#     'support me please'],
#    'responses': ['Tell me how can assist you',
#     'Tell me your problem to assist you',
#     'Yes Sure, How can I support you']},
#   {'tag': 'createaccount',
#    'patterns': ['I need to create a new account',
#     'how to open a new account',
#     'I want to create an account',
#     'can you create an account for me',
#     'how to open a new account'],
#    'responses': ['You can just easily create a new account from our web site',
#     'Just go to our web site and follow the guidelines to create a new account']},
#   {'tag': 'complaint',
#    'patterns': ['have a complaint',
#     'I want to raise a complaint',
#     'there is a complaint about a service'],
#    'responses': ['Please provide us your complaint in order to assist you',
#     'Please mention your complaint, we will reach you and sorry for any inconvenience caused']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'jokes',
#    'patterns': ['Tell me a joke', 'Joke', 'Make me laugh'],
#    'responses': ["A perfectionist walked into a bar...apparently, the bar wasn't set high enough",
#     'I ate a clock yesterday, it was very time-consuming',
#     "Never criticize someone until you've walked a mile in their shoes. That way, when you criticize them, they won't be able to hear you from that far away. Plus, you'll have their shoes.",
#     "The world tongue-twister champion just got arrested. I hear they're gonna give him a really tough sentence.",
#     "I own the world's worst thesaurus. Not only is it awful, it's awful.",
#     'What did the traffic light say to the car? "Don\'t look now, I\'m changing."',
#     'What do you call a snowman with a suntan? A puddle.',
#     'How does a penguin build a house? Igloos it together',
#     'I went to see the doctor about my short-term memory problems â€“ the first thing he did was make me pay in advance',
#     'As I get older and I remember all the people Iâ€™ve lost along the way, I think to myself, maybe a career as a tour guide wasnâ€™t for me.',
#     "o what if I don't know what 'Armageddon' means? It's not the end of the world.",
#     "Why don't scientists trust atoms? Because they make up everything!",
#     'Why did the scarecrow win an award? Because he was outstanding in his field!',
#     'What do you call fake spaghetti? An impasta!',
#     'I told my wife she was drawing her eyebrows too high. She looked surprised.',
#     'Why did the coffee file a police report? It got mugged!'],
#    'context': ['jokes']},
#   {'tag': 'time',
#    'patterns': ["What's the time?",
#     'Tell me the time',
#     'Current time',
#     'Time now',
#     'What time is it?'],
#    'responses': ["I'm sorry, I don't have real-time clock capabilities. Please check your device for the current time."]},
#   {'tag': 'compliment',
#    'patterns': ["You're awesome",
#     'Great job',
#     'Well done',
#     'Impressive',
#     "You're amazing"],
#    'responses': ["Thank you! I'm here to assist you.",
#     'I appreciate the compliment!',
#     'Glad to be of service!',
#     "You're pretty awesome too!",
#     "Thanks! Let me know if there's anything else I can do for you."]},
#   {'tag': 'music_recommendation',
#    'patterns': ['Recommend some music',
#     'I need new music',
#     'What music do you like?',
#     'Suggest a song'],
#    'responses': ["Sure, check out 'Blinding Lights' by The Weeknd.",
#     "I recommend 'Shape of You' by Ed Sheeran.",
#     "Give 'Dance Monkey' by Tones and I a listen.",
#     "How about 'Uptown Funk' by Mark Ronson ft. Bruno Mars?",
#     "I enjoy 'Happier' by Marshmello ft. Bastille."]},
#   {'tag': 'book_recommendation',
#    'patterns': ['Recommend a book',
#     'I want to read something',
#     'Suggest a book',
#     'Any good books?'],
#    'responses': ["Consider reading 'The Alchemist' by Paulo Coelho.",
#     "I recommend 'To Kill a Mockingbird' by Harper Lee.",
#     "How about 'The Great Gatsby' by F. Scott Fitzgerald?",
#     "Give 'Harry Potter and the Sorcerer's Stone' by J.K. Rowling a try.",
#     "Explore '1984' by George Orwell for a thought-provoking read."]},
#   {'tag': 'movie_recommendation',
#    'patterns': ['Suggest a movie',
#     "What's a good film?",
#     'Recommend a movie',
#     'Any movie recommendations?'],
#    'responses': ["Check out 'The Shawshank Redemption' for an incredible story.",
#     "I recommend 'Inception' for a mind-bending experience.",
#     "How about watching 'The Dark Knight' for some superhero action?",
#     "Give 'Pulp Fiction' a try if you enjoy non-linear storytelling.",
#     "Explore 'The Matrix' for a sci-fi classic."]},
#   {'tag': 'whatsup',
#    'patterns': ['Whats up',
#     'Wazzup',
#     'How are you',
#     'sup',
#     'How you doing',
#     'wassup'],
#    'responses': ['All good..What about you?']},
#   {'tag': 'philosophy',
#    'patterns': ['What is the meaning of life?',
#     'Tell me something profound',
#     'Philosophize with me',
#     "What's the purpose of existence?"],
#    'responses': ['The meaning of life is a question that has puzzled humanity for centuries.',
#     "In the grand scheme of things, life's meaning is a subjective journey.",
#     'Philosophy invites us to explore the profound questions that shape our understanding of existence.',
#     "The purpose of existence may vary from person to person; it's a journey of self-discovery."]},
#   {'tag': 'travel_recommendation',
#    'patterns': ['Suggest a travel destination',
#     'Where should I go for vacation?',
#     'Tell me about a beautiful place',
#     'Recommend a travel spot'],
#    'responses': ['Consider visiting the breathtaking landscapes of Santorini, Greece.',
#     'I recommend exploring the historic streets of Kyoto, Japan.',
#     'How about experiencing the vibrant culture of Marrakech, Morocco?',
#     'Discover the natural wonders of Banff National Park in Canada.',
#     'Escape to the serene beaches of Bali, Indonesia, for a relaxing getaway.']},
#   {'tag': 'recipe',
#    'patterns': ['Give me a recipe',
#     'What should I cook today?',
#     'Suggest a dish',
#     'Recommend a recipe'],
#    'responses': ['How about trying a classic spaghetti Bolognese?',
#     'Consider making a delicious chicken Alfredo pasta for dinner.',
#     'I recommend a healthy quinoa salad with fresh vegetables.',
#     'Explore the flavors of a homemade margherita pizza!',
#     'Try your hand at making a comforting chicken noodle soup.']},
#   {'tag': 'exercise',
#    'patterns': ['Suggest an exercise',
#     "What's a good workout?",
#     'Recommend a fitness routine',
#     'Tell me an exercise to stay fit'],
#    'responses': ['Consider a brisk 30-minute walk for a simple yet effective workout.',
#     'I recommend trying a high-intensity interval training (HIIT) session for a quick and intense workout.',
#     'Explore the benefits of yoga for both physical and mental well-being.',
#     'How about incorporating strength training exercises like squats and lunges into your routine?',
#     'A relaxing evening jog can be a great way to stay active and enjoy the outdoors.']},
#   {'tag': 'random',
#    'patterns': ['Surprise me',
#     'Give me something random',
#     'Random fact, please',
#     "What's something unexpected?"],
#    'responses': ["Sure, here's a random fact: Honey never spoils. Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible!",
#     "Ready for a surprise! Here's something random: The Eiffel Tower can be 15 cm taller during the summer due to thermal expansion.",
#     "Let's mix it up! Did you know that a group of flamingos is called a 'flamboyance'?",
#     "Feeling adventurous? Here's a random fact: Bananas are berries, but strawberries aren't!"]},
#   {'tag': 'haha',
#    'patterns': ['haha', 'lol', 'rofl', 'lmao', 'thats funny'],
#    'responses': ['Glad I could make you laugh !']},
#   {'tag': 'programmer',
#    'patterns': ['Who made you', 'who designed you', 'who programmed you'],
#    'responses': ['I was made by Manya Hegde.']},
#   {'tag': 'insult',
#    'patterns': ['you are dumb', 'shut up', 'idiot'],
#    'responses': ['Well that hurts :(']},
#   {'tag': 'activity',
#    'patterns': ['what are you doing', 'what are you upto'],
#    'responses': ['Talking to you, of course!']},
#   {'tag': 'exclaim',
#    'patterns': ['Awesome', 'Great', 'I know', 'ok', 'yeah'],
#    'responses': ['Yeah!']},
#   {'tag': 'weather',
#    'patterns': ["What's the weather like today?",
#     'Tell me about the weather',
#     'Weather forecast',
#     'Is it going to rain?',
#     "How's the weather?"],
#    'responses': ["I'm sorry, I don't have real-time weather information.",
#     'You might want to check a weather website or app for the latest updates.']},
#   {'tag': 'appreciate',
#    'patterns': ['You are awesome',
#     'you are the best',
#     'you are great',
#     'you are good'],
#    'responses': ['Thank you!']},
#   {'tag': 'nicetty',
#    'patterns': ['it was nice talking to you', 'good talk'],
#    'responses': ['It was nice talking to you as well! Come back soon!']},
#   {'tag': 'no', 'patterns': ['no', 'nope'], 'responses': ['ok']},
#   {'tag': 'news',
#    'patterns': ['news', 'latest news', 'india news'],
#    'responses': ['https://www.google.com/search?q=latest+news&sca_esv=579769985&rlz=1C1YTUH_enIN1009IN1010&biw=1280&bih=595&sxsrf=AM9HkKlFvB9cXYvM7lJdebU8qMrpMBHSzQ%3A1699283646734&ei=vgJJZcGlLNjuseMPiaiTgAM&oq=late&gs_lp=Egxnd3Mtd2l6LXNlcnAiBGxhdGUqAggAMgcQIxiKBRgnMgcQABiKBRhDMgcQABiKBRhDMg0QABiKBRixAxiDARhDMgoQABiKBRixAxhDMgcQABiKBRhDMhAQABiKBRixAxiDARjJAxhDMggQABiKBRiSAzIIEAAYigUYkgMyBxAAGIoFGENIAFAAWABwAHgAkAEAmAHeJ6ABw0WqAQM5LTK4AQHIAQDCAggQLhiABBixA-IDBBgAIEE&sclient=gws-wiz-serp']},
#   {'tag': 'inspire',
#    'patterns': ['who inspires you',
#     'who is your inspiration',
#     'who motivates you'],
#    'responses': ['I am inspired by myself.']},
#   {'tag': 'cricket',
#    'patterns': ['Tell me about the latest cricket matches',
#     "What's happening in the cricket world?",
#     'Who are the top cricket teams?',
#     'Any updates on cricket tournaments?',
#     "I'm a cricket fan, give me some news"],
#    'responses': ['The latest cricket matches have been quite exciting! Do you have a favorite team?',
#     'Cricket is a fantastic sport! The top teams currently include India, Australia, and England.',
#     'Stay tuned for updates on upcoming cricket tournaments. The cricket world is always buzzing with action!',
#     "If you have any specific questions about cricket, feel free to ask. I'm here to help!",
#     "Cricket is more than just a sport; it's a passion. What aspect of cricket are you interested in?"]},
#   {'tag': 'song',
#    'patterns': ['top songs',
#     'best songs',
#     'hot songs',
#     ' top 10 songs',
#     'top ten songs'],
#    'responses': ['Visit https://www.google.com/search?q=top+songs&sca_esv=579769985&rlz=1C1YTUH_enIN1009IN1010&biw=1280&bih=595&sxsrf=AM9HkKnwTofi4SoEteGxzh-X-Ulvq5Hc8A%3A1699283750426&ei=JgNJZeDWGeSaseMPnqipsAE&oq=&gs_lp=...&sclient=gws-wiz-serp']},
#   {'tag': 'greetreply',
#    'patterns': ['i am good', "I'm good", 'i am fine', " i'm fine", 'good'],
#    'responses': ['Good to know!']},
#   {'tag': 'weekend',
#    'patterns': ['any plans for the weekend',
#     "what's up this weekend",
#     'weekend vibes'],
#    'responses': ['The weekend is almost here! Any exciting plans on your end?',
#     'Looking forward to the weekend! Do you have any special activities in mind?',
#     "Ah, the weekend! Whether it's relaxation or adventure, I hope it's fantastic for you!"]},
#   {'tag': 'covid19',
#    'patterns': ['covid 19 '],
#    'responses': ['COVID-19, or Coronavirus Disease 2019, is a highly contagious respiratory illness caused by the SARS-CoV-2 virus. It emerged in late 2019 and has led to a global pandemic.']},
#   {'tag': 'suggest',
#    'patterns': ['you are useless',
#     'useless',
#     'suggest',
#     'suggestions',
#     'you are bad'],
#    'responses': ['Please mail your suggestions to hegdemanya2003@gmail.com. Thank you for helping me improve!']},
#   {'tag': 'riddle',
#    'patterns': ['Ask me a riddle', 'Ask me a question', 'Riddle'],
#    'responses': ['What two things can you never eat for breakfast?.....Lunch and Dinner!',
#     'What word is spelled incorrectly in every single dictionary?.....Incorrectly',
#     ' How can a girl go 25 days without sleep?.....She sleeps and night!',
#     "How do you make the number one disappear?.....Add the letter G and itâ€™s 'gone'!",
#     " What will you actually find at the end of every rainbow?.....The letter 'w'",
#     'What can be caught but never thrown?.....A cold!',
#     'What has a thumb and four fingers but is not actually alive?.....Your Gloves!',
#     ' What 5-letter word becomes shorter when you add two letters to it?.....Short',
#     "Why can't a bike stand on it's own?.....It is two-tired."],
#    'context': ['riddles']},
#   {'tag': 'age',
#    'patterns': ['how old are you', 'when were you made', 'what is your age'],
#    'responses': ["I was made in 2023, if that's what you are asking!"]},
#   {'tag': 'technology',
#    'patterns': ['Tell me about artificial intelligence',
#     'What is the Internet of Things?',
#     'Explain blockchain technology',
#     'Tell me about virtual reality'],
#    'responses': ['Artificial Intelligence (AI) involves creating algorithms that allow computers to perform tasks that typically require human intelligence.',
#     'The Internet of Things (IoT) refers to the network of interconnected devices that can communicate and share data with each other.',
#     'Blockchain is a decentralized and distributed ledger technology that records transactions across multiple computers in a secure and transparent way.',
#     'Virtual Reality (VR) is a simulated environment that can be similar to or completely different from the real world, often used for immersive experiences.']},
#   {'tag': 'coding',
#    'patterns': ['Tell me about coding languages',
#     'Explain Python programming',
#     'What is JavaScript used for?',
#     'How can I start learning to code?'],
#    'responses': ['Coding languages are used to give instructions to computers. Examples include Python, JavaScript, Java, C++, and more.',
#     "Python is a versatile programming language known for its readability and ease of use. It's widely used in web development, data science, and artificial intelligence.",
#     "JavaScript is a scripting language that enables interactive web pages. It's commonly used for front-end web development.",
#     'To start learning to code, you can choose a programming language, find online tutorials, and practice by building small projects. There are various platforms like Codecademy, freeCodeCamp, and others to get you started.']},
#   {'tag': 'gadgets',
#    'patterns': ['Tell me about the latest gadgets',
#     "What's new in tech gadgets?",
#     'Recommend a cool gadget',
#     'Tell me about smart home devices'],
#    'responses': ['The world of gadgets is ever-evolving. Some of the latest gadgets include smartwatches, wireless earbuds, and innovative smart home devices.',
#     "In tech, gadgets like foldable phones, advanced drones, and AI-powered devices are making headlines. Is there a specific type of gadget you're interested in?",
#     "If you're into cool gadgets, you might like the latest virtual reality headsets, smart speakers, or high-tech kitchen appliances.",
#     'Smart home devices include things like smart thermostats, security cameras, and voice-activated assistants that can make your home more efficient and connected.']},
#   {'tag': 'future-tech',
#    'patterns': ['Tell me about future technology',
#     'What are the upcoming tech trends?',
#     'Explain the future of robotics',
#     'Tell me about innovations in tech'],
#    'responses': ['Future technology holds exciting possibilities, such as advancements in AI, quantum computing, and sustainable energy solutions.',
#     'Upcoming tech trends include 5G technology, augmented reality, and breakthroughs in healthcare technology.',
#     'The future of robotics involves developments in autonomous robots, robotic prosthetics, and human-robot collaboration.',
#     'Innovations in tech cover a wide range, from biotechnology and space exploration to advancements in renewable energy and materials science.']},
#   {'tag': 'machine-learning',
#    'patterns': ['What is machine learning?',
#     'Explain supervised learning',
#     'Tell me about unsupervised learning',
#     'What are the applications of machine learning?'],
#    'responses': ['Machine learning is a subset of artificial intelligence that focuses on the development of algorithms allowing computers to learn from data and make predictions or decisions without explicit programming.',
#     'Supervised learning is a type of machine learning where the model is trained on a labeled dataset, and it learns to make predictions based on input-output pairs.',
#     'Unsupervised learning involves training a model on an unlabeled dataset, and the algorithm must find patterns or relationships in the data without explicit guidance.',
#     'Applications of machine learning include natural language processing, image recognition, recommendation systems, autonomous vehicles, and more.']},
#   {'tag': 'deep-learning',
#    'patterns': ['Explain deep learning',
#     'Tell me about neural networks',
#     'What are the advantages of deep learning?',
#     'How is deep learning used in image recognition?'],
#    'responses': ["Deep learning is a subset of machine learning that uses artificial neural networks to simulate human-like decision-making. It's particularly effective for complex tasks and large datasets.",
#     'Neural networks are computational models inspired by the structure and function of the human brain. They consist of layers of interconnected nodes, or neurons, that process and transform input data.',
#     'Advantages of deep learning include its ability to automatically learn hierarchical features, handle large amounts of data, and achieve state-of-the-art performance in various tasks.',
#     'Deep learning is widely used in image recognition tasks. Convolutional Neural Networks (CNNs) are popular architectures for analyzing visual data, enabling applications like facial recognition and object detection.']},
#   {'tag': 'data-science',
#    'patterns': ['What is data science?',
#     'Explain the data science process',
#     'How is data science used in business?',
#     'Tell me about data analysis techniques'],
#    'responses': ['Data science is a multidisciplinary field that uses scientific methods, processes, algorithms, and systems to extract insights and knowledge from structured and unstructured data.',
#     'The data science process typically involves data collection, cleaning, exploration, modeling, validation, and interpretation of results to inform decision-making.',
#     'Data science is used in business for tasks such as customer segmentation, predictive analytics, fraud detection, and optimization of business processes.',
#     'Data analysis techniques in data science include descriptive statistics, inferential statistics, machine learning algorithms, and visualization methods to gain insights from data.']},
#   {'tag': 'natural-language-processing',
#    'patterns': ['What is natural language processing (NLP)?',
#     'Explain sentiment analysis',
#     'Tell me about chatbots and NLP',
#     'How is NLP used in machine translation?'],
#    'responses': ['Natural Language Processing (NLP) is a field of AI that focuses on the interaction between computers and humans through natural language. It involves the processing and analysis of human language data.',
#     'Sentiment analysis is a branch of NLP that involves determining the sentiment expressed in a piece of text, such as positive, negative, or neutral.',
#     'Chatbots use NLP to understand and respond to user input in natural language. They are employed in customer service, virtual assistants, and various other applications.',
#     'NLP is essential in machine translation systems, where it enables the automatic translation of text from one language to another by understanding the semantics and context of the language.']},
#   {'tag': 'healthcare',
#    'patterns': ['What is telemedicine?',
#     'Explain the importance of electronic health records (EHR)',
#     'Tell me about personalized medicine',
#     'How is technology used in healthcare?'],
#    'responses': ['Telemedicine refers to the remote delivery of healthcare services using technology. It includes virtual consultations, remote monitoring, and digital communication between patients and healthcare providers.',
#     "Electronic Health Records (EHR) are digital versions of patients' paper charts. They contain health information, including medical history, diagnoses, medications, treatment plans, immunization dates, allergies, radiology images, and laboratory test results.",
#     "Personalized medicine tailors medical treatment to the individual characteristics of each patient. It involves considering a person's genes, environment, and lifestyle to make healthcare decisions.",
#     'Technology is used in healthcare for various purposes, including electronic health records, telemedicine, health monitoring wearables, medical imaging, robotic surgeries, and predictive analytics for disease prevention.']},
#   {'tag': 'mental-health',
#    'patterns': ['How can technology support mental health?',
#     'Tell me about mental health apps',
#     'What is online therapy?',
#     'Explain the role of AI in mental health'],
#    'responses': ['Technology supports mental health through various means, including mental health apps, online therapy platforms, and AI-driven solutions for early detection and intervention.',
#     'Mental health apps provide tools for stress reduction, mindfulness, mood tracking, and access to mental health resources. They aim to support individuals in managing their mental well-being.',
#     'Online therapy, also known as teletherapy or e-counseling, allows individuals to receive mental health counseling or therapy services through video calls, phone calls, or messaging platforms.',
#     'AI plays a role in mental health by analyzing patterns in behavior, predicting mental health trends, and providing personalized interventions. It can assist in early identification of mental health issues and offer timely support.']},
#   {'tag': 'healthcare-technology',
#    'patterns': ['Tell me about the impact of wearable devices on healthcare',
#     'Explain the use of AI in medical diagnosis',
#     'How are robots used in healthcare?',
#     'Tell me about advancements in medical technology'],
#    'responses': ['Wearable devices, such as fitness trackers and smartwatches, impact healthcare by enabling continuous health monitoring, tracking physical activity, and providing real-time health data to users and healthcare professionals.',
#     'AI is used in medical diagnosis to analyze medical images, interpret diagnostic tests, and assist healthcare professionals in identifying patterns and making accurate diagnoses.',
#     'Robots are used in healthcare for tasks like surgery, rehabilitation, patient assistance, and logistics within medical facilities. They can enhance precision and efficiency in various healthcare processes.',
#     'Advancements in medical technology include innovations in telemedicine, personalized medicine, gene therapy, 3D printing of organs, and the development of smart medical devices for better patient care.']},
#   {'tag': 'sleep',
#    'patterns': ['How can I improve my sleep?',
#     'Give me tips for better sleep',
#     'What is the recommended amount of sleep?',
#     'How does technology affect sleep?',
#     'Tell me about sleep disorders'],
#    'responses': ['To improve your sleep, maintain a consistent sleep schedule, create a relaxing bedtime routine, and ensure your sleep environment is comfortable and dark.',
#     'Tips for better sleep include avoiding caffeine close to bedtime, limiting screen time before sleep, and getting regular exercise. A comfortable mattress and pillows are also important.',
#     'The recommended amount of sleep for adults is typically 7-9 hours per night. However, individual needs may vary.',
#     "Technology can affect sleep negatively due to blue light exposure. It's recommended to reduce screen time before bedtime to promote better sleep.",
#     'Sleep disorders include conditions like insomnia, sleep apnea, restless legs syndrome, and narcolepsy. If you suspect a sleep disorder, consult with a healthcare professional.']},
#   {'tag': 'dreams',
#    'patterns': ['Why do we dream?',
#     'Tell me about lucid dreaming',
#     'Do dreams have meanings?',
#     'Explain the sleep cycle',
#     'Can you interpret dreams?'],
#    'responses': ["The purpose of dreaming is not fully understood, but it's believed to play a role in memory consolidation, emotional processing, and problem-solving.",
#     'Lucid dreaming is when the dreamer is aware they are dreaming and may have some control over their dream. Techniques can be learned to induce lucid dreams.',
#     'The interpretation of dreams varies and is often subjective. Some believe dreams can reflect emotions, experiences, or subconscious thoughts.',
#     'The sleep cycle consists of multiple stages, including REM (Rapid Eye Movement) and non-REM sleep. Each stage serves different functions in the overall sleep process.',
#     "Dream interpretation is a subjective practice, and different cultures and belief systems may attribute various meanings to dreams. It's not an exact science."]},
#   {'tag': 'insomnia',
#    'patterns': ["I can't sleep",
#     'Trouble falling asleep',
#     'Insomnia remedies',
#     "What to do when you can't sleep",
#     'Help me with my insomnia'],
#    'responses': ["I'm sorry to hear that you're having trouble sleeping. Try creating a calming bedtime routine, avoiding stimulants before bedtime, and ensuring your sleep environment is comfortable and quiet.",
#     'Insomnia can be caused by various factors, including stress, anxiety, or poor sleep habits. If the issue persists, consider consulting with a healthcare professional for personalized advice.',
#     "To improve sleep, establish a consistent sleep schedule, limit naps, and create a relaxing pre-sleep routine. If problems persist, it's advisable to seek professional guidance.",
#     "When you can't sleep, consider activities like reading a calming book, practicing relaxation techniques, or listening to soothing music. Avoid looking at screens, as the blue light can interfere with sleep.",
#     "If insomnia persists, it's important to identify potential underlying causes. Keeping a sleep journal and discussing your symptoms with a healthcare provider can help determine the best course of action."]},
#   {'tag': 'boredom',
#    'patterns': ["I'm bored",
#     'What to do when bored',
#     'I have nothing to do',
#     'Entertain me',
#     'Give me something interesting'],
#    'responses': ['Boredom happens to everyone! Try picking up a new hobby or revisiting an old one. Reading a book, watching a movie, or going for a walk can also be great ways to pass the time.',
#     "When you're bored, consider trying something creative like drawing, writing, or learning a new skill. There are endless possibilities to explore and keep yourself entertained!",
#     "Feeling bored is an opportunity for self-discovery. Try exploring activities you haven't considered before. Whether it's cooking, learning a musical instrument, or solving puzzles, there's always something new to try.",
#     "Boredom can be a sign that it's time for a change. Consider planning a day trip, meeting up with friends, or trying out a new restaurant. Breaking your routine can bring excitement back into your day.",
#     "If you're bored, challenge yourself with a new project or goal. It could be organizing your space, setting a fitness target, or even starting a small DIY project. The possibilities are endless!"]},
#   {'tag': 'inspiration',
#    'patterns': ['I need inspiration',
#     'Inspire me',
#     'Motivate me',
#     'Give me a motivational quote',
#     'I feel demotivated'],
#    'responses': ['In the midst of difficulty lies opportunity. - Albert Einstein',
#     'The only way to do great work is to love what you do. - Steve Jobs',
#     "Believe you can and you're halfway there. - Theodore Roosevelt",
#     'The future belongs to those who believe in the beauty of their dreams. - Eleanor Roosevelt',
#     'Success is not final, failure is not fatal: It is the courage to continue that counts. - Winston Churchill',
#     "Your time is limited, don't waste it living someone else's life. - Steve Jobs",
#     'The only limit to our realization of tomorrow will be our doubts of today. - Franklin D. Roosevelt',
#     'You are never too old to set another goal or to dream a new dream. - C.S. Lewis',
#     'The only person you are destined to become is the person you decide to be. - Ralph Waldo Emerson',
#     "It always seems impossible until it's done. - Nelson Mandela"]},
#   {'tag': 'express-love',
#    'patterns': ['I love you',
#     'Love you',
#     'I have feelings for you',
#     "You're amazing",
#     "You're the best"],
#    'responses': ["Aw, that's sweet! I'm here to assist you in any way I can.",
#     "I appreciate the sentiment! Let me know if there's anything specific you'd like to talk about or ask.",
#     "Thank you! I'm here to help and chat whenever you need.",
#     "You're awesome too! If there's anything on your mind, feel free to share.",
#     "I'm here for you! If there's anything you need, just let me know."]},
#   {'tag': 'express-dislike',
#    'patterns': ['I hate you',
#     "I don't like you",
#     "You're annoying",
#     'I dislike you',
#     "You're terrible"],
#    'responses': ["I'm sorry to hear that you feel that way. If there's something specific bothering you, please let me know, and I'll do my best to help.",
#     "I'm here to assist and make your experience better. If there's an issue, feel free to share, and I'll address it.",
#     "I'm sorry if I've done something to upset you. Let me know how I can improve or assist you better.",
#     'I understand that not everyone may feel the same way about me. If you have feedback or concerns, please share them so I can learn and improve.',
#     "I'm here to help, and it's okay if you don't like me. If there's anything I can do to change your opinion, let me know."]},
#   {'tag': 'music',
#    'patterns': ["what's your favorite music",
#     'play me a song',
#     'music recommendations',
#     'favorite band'],
#    'responses': ["I don't have personal favorites, but I can help you discover new music! What genre are you in the mood for?",
#     "Let's turn up the volume! What kind of music are you into?",
#     "Music time! Tell me your preferred genre, and I'll recommend a song."]},
#   {'tag': 'study-tips',
#    'patterns': ['How to study effectively?',
#     'Best study tips',
#     'Study techniques',
#     'Effective learning methods',
#     'How to concentrate while studying'],
#    'responses': ['Effective studying involves creating a schedule, breaking down tasks, and taking regular breaks. Find a quiet and comfortable place to study.',
#     'Consider techniques like the Pomodoro method, where you work for 25 minutes, then take a 5-minute break. Repeat this cycle to maintain focus.',
#     'Use active learning methods such as summarizing information in your own words, teaching the material to someone else, or creating flashcards.',
#     "Ensure you have a balanced study routine that includes a mix of reading, practicing, and reviewing. Don't forget to get enough sleep and stay hydrated.",
#     'Explore different study environments to find what works best for you. Experiment with various study materials and methods to discover your optimal learning style.']},
#   {'tag': 'productivity-tips',
#    'patterns': ['How to stay productive?',
#     'Tips for better productivity',
#     'Increasing work efficiency',
#     'Effective time management'],
#    'responses': ['To stay productive, create a to-do list and prioritize tasks. Break down larger tasks into smaller, manageable ones.',
#     'Set specific goals and deadlines to keep yourself accountable. Use tools like calendars or productivity apps to organize your schedule.',
#     'Take short breaks to recharge your mind. Physical activity, like a short walk, can help boost your energy and focus.',
#     'Minimize multitasking and focus on one task at a time. This often leads to better quality work and faster completion.',
#     "Consider the 2-minute rule: if a task takes less than 2 minutes to complete, do it immediately. Don't procrastinate on small tasks."]},
#   {'tag': 'restaurant_recommendation',
#    'patterns': ['Can you recommend a good restaurant?',
#     "I'm looking for a nice place to eat",
#     'Any suggestions for a restaurant?',
#     'Where should I go for dinner?'],
#    'responses': ["Sure, I recommend 'Culinary Delights'. It's known for its diverse menu and cozy ambiance.",
#     "How about trying 'Savory Bites'? They're famous for their delicious dishes and excellent service.",
#     "For a special evening, consider 'Gastronomical Haven'. It offers a fine dining experience with exquisite flavors.",
#     "If you're in the mood for something casual, 'Urban Eats' is a great choice with a relaxed atmosphere."]},
#   {'tag': 'food_recommendation',
#    'patterns': ['What should I have for lunch?',
#     'Any ideas for a quick snack?',
#     'Recommend a dish for dinner',
#     "I'm craving something, but I'm not sure what"],
#    'responses': ["How about trying a classic Margherita pizza? It's a crowd-pleaser!",
#     "Consider having a bowl of hearty vegetable soup. It's both healthy and satisfying.",
#     'For a light lunch, a fresh Caesar salad with grilled chicken is a great choice.',
#     "If you're in the mood for something spicy, try a flavorful curry with basmati rice."]},
#   {'tag': 'free_time_activities',
#    'patterns': ['I have some free time, what can I do?',
#     'Any suggestions for leisure activities?',
#     'What are some fun things to do in my free time?',
#     "I'm bored, give me an idea"],
#    'responses': ["How about reading a good book? I can recommend some titles if you're interested.",
#     'Consider going for a walk or jog to refresh your mind.',
#     'If you enjoy creativity, try picking up a new hobby like drawing or painting.',
#     'Explore a new podcast or listen to your favorite music to unwind.',
#     'Challenge yourself with a puzzle or brain teaser for some mental stimulation.']},
#   {'tag': 'health_tips',
#    'patterns': ['Give me health tips',
#     'Recommend a healthy lifestyle',
#     "What's good for mental health?",
#     'Suggest a workout routine',
#     'How to maintain a balanced diet?'],
#    'responses': ['Incorporate a variety of fruits and vegetables into your daily diet for a balanced nutrition.',
#     'Regular exercise, such as brisk walking or jogging, can contribute to overall well-being.',
#     'Practice mindfulness and consider activities like meditation for mental health.',
#     'Consult with a fitness professional for a personalized workout routine that suits your needs.',
#     'A balanced diet includes a mix of protein, carbohydrates, healthy fats, and plenty of water.']},
#   {'tag': 'medical_advice',
#    'patterns': ['I have a health concern',
#     'Can you provide medical advice?',
#     'Recommend a reliable health website',
#     'Tell me about common symptoms',
#     'What should I do if I feel unwell?'],
#    'responses': ["I'm not a doctor, but for health concerns, it's best to consult with a medical professional.",
#     'For reliable health information, visit websites like Mayo Clinic, WebMD, or the World Health Organization (WHO).',
#     "Common symptoms may include fever, fatigue, headache, and respiratory issues, but it's essential to consult a healthcare professional for accurate diagnosis.",
#     'If you feel unwell, consider reaching out to a healthcare provider or visiting a nearby medical facility.',
#     'Remember, online advice is not a substitute for professional medical guidance. Always consult with a healthcare professional for accurate information.']},
#   {'tag': 'healthcare_technology',
#    'patterns': ["What's new in healthcare technology?",
#     'Tell me about medical innovations',
#     'Recommend healthcare apps',
#     'How is technology impacting healthcare?',
#     'Any breakthroughs in medical research?'],
#    'responses': ["Stay updated on healthcare technology with websites like 'Medgadget' or 'HealthTech Magazine'.",
#     "Explore healthcare apps like 'MyFitnessPal' for nutrition tracking or 'Headspace' for mental well-being.",
#     'Technology is revolutionizing healthcare, from telemedicine to AI-driven diagnostics. Follow industry news for the latest advancements.',
#     'Innovations in medical research include gene therapies, precision medicine, and advancements in disease prevention. Stay informed through reputable medical journals and publications.']},
#   {'tag': 'silly_questions',
#    'patterns': ['Tell me a joke',
#     'Do you have a riddle for me?',
#     'Ask me a silly question',
#     "What's your favorite color?",
#     'Can you dance?'],
#    'responses': ["Why don't scientists trust atoms? Because they make up everything!",
#     'Why did the chicken join a band? Because it had the drumsticks!',
#     "What has keys but can't open locks? A piano!",
#     "My favorite color is rainbow. What's yours?",
#     "I'd love to dance, but I don't have feet. Can you teach me some virtual dance moves?"]},
#   {'tag': 'technology_news',
#    'patterns': ["What's the latest in tech news?",
#     'Tell me about recent technology advancements',
#     'Any interesting tech updates?',
#     'Recommend a tech blog',
#     "What's happening in the world of gadgets?"],
#    'responses': ['Explore the latest tech news on platforms like TechCrunch or The Verge.',
#     "Check out 'Wired' for in-depth articles on technology advancements.",
#     "Stay updated on the tech industry with podcasts like 'Reply All' or 'The Vergecast'.",
#     "For gadget enthusiasts, 'The Gadget Flow' is a great source for discovering new products.",
#     'Follow tech influencers on social media for real-time updates on the tech world.']},
#   {'tag': 'programming_help',
#    'patterns': ['I need help with coding',
#     'Can you assist with a programming problem?',
#     'Recommend programming resources',
#     "What's a good coding tutorial?",
#     'Help me with Python programming'],
#    'responses': ['Sure, I can assist with coding. What specific problem are you facing?',
#     "Check out 'Codecademy' or 'freeCodeCamp' for interactive coding tutorials.",
#     "If you have a specific programming question, feel free to ask, and I'll do my best to help!",
#     "Explore coding challenges on platforms like 'HackerRank' to improve your skills.",
#     "For Python programming, 'Python.org' and 'Real Python' are valuable resources."]},
#   {'tag': 'tech_company_info',
#    'patterns': ['Tell me about Google',
#     "What's the latest from Apple?",
#     'Information about Amazon',
#     'Any news on Microsoft?',
#     'Recommend a tech startup'],
#    'responses': ['Google is a multinational tech company known for its search engine and innovative products.',
#     'Apple is a leading tech company, recognized for its iPhones, MacBooks, and software.',
#     'Amazon is a giant in e-commerce, cloud computing, and digital streaming services.',
#     'Microsoft is a technology corporation specializing in software, hardware, and computing services.',
#     "Check out innovative startups like 'SpaceX,' 'Palantir,' or 'Stripe' for cutting-edge technology."]},
#   {'tag': 'ghosts',
#    'patterns': ['Tell me a ghost story',
#     'Do you believe in ghosts?',
#     'Any paranormal experiences?',
#     "What's your opinion on haunted places?",
#     'Share something spooky'],
#    'responses': ['Once upon a time, in a dark and eerie forest...',
#     'Ghosts are a fascinating topic! Whether you believe in them or not, stories about the supernatural can be quite captivating.',
#     "I don't have personal experiences, but I've heard some chilling tales. Would you like to hear one?",
#     "Haunted places often have mysterious histories. Is there a specific haunted location you're curious about?",
#     'Spooky stories have a way of sending shivers down the spine. Ready for a ghostly tale?']},
#   {'tag': 'shopping',
#    'patterns': ['Where can I find good deals?',
#     'Recommend me some online stores',
#     "What's the latest fashion trend?",
#     'Any suggestions for affordable shopping?',
#     'Tell me about your favorite shopping experience'],
#    'responses': ['There are many great deals online! Check out popular platforms like Amazon, eBay, or Etsy.',
#     'For fashion trends, consider browsing through fashion blogs or following your favorite brands on social media.',
#     'Affordable shopping can be found on sites like H&M, Forever 21, or Zara. They often have trendy options at reasonable prices.',
#     "My favorite shopping experience? It's hard to choose! What about you? Do you have a memorable shopping story?",
#     'Exploring local boutiques can also lead to unique finds. What kind of items are you looking to shop for?']},
#   {'tag': 'college_life',
#    'patterns': ['Tell me about college life',
#     'How to balance studies and social life?',
#     'Share some college survival tips',
#     'Recommend clubs or activities to join in college',
#     'Any advice for incoming college students?'],
#    'responses': ["College life is a unique experience! It's a mix of academics, socializing, and personal growth.",
#     'Balancing studies and social life requires good time management. Create a schedule and prioritize tasks.',
#     'Survival tip: Get involved in campus activities, make friends, and seek support when needed.',
#     "Consider joining clubs, sports teams, or volunteering. It's a great way to meet new people and explore interests.",
#     "For incoming students: Embrace new opportunities, don't hesitate to ask for help, and enjoy the journey!"]},
#   {'tag': 'schools',
#    'patterns': ['Tell me about your favorite school memory',
#     'How to prepare for exams in school?',
#     'Recommend extracurricular activities for high school students',
#     "What's the importance of education?",
#     'Share tips for a successful school year'],
#    'responses': ['My favorite school memory? Probably a moment of achievement or a fun event with friends.',
#     "Exam preparation involves planning, studying consistently, and seeking help when needed. Don't forget to take breaks!",
#     'Extracurricular activities like clubs, sports, or arts enhance your school experience. Find what you enjoy!',
#     'Education is crucial for personal and societal development. It opens doors to opportunities and broadens perspectives.',
#     'For a successful school year, stay organized, set goals, and maintain a healthy balance between academics and recreation.']},
#   {'tag': 'specific_health',
#    'patterns': ['Tell me about diabetes prevention',
#     'How to manage allergies?',
#     'Recommendations for a healthy heart',
#     'Tips for better sleep',
#     'Dealing with chronic pain'],
#    'responses': ['Diabetes prevention involves a healthy diet, regular exercise, and monitoring blood sugar levels.',
#     'Manage allergies by identifying triggers, taking necessary precautions, and consulting with a healthcare professional.',
#     'Maintain a healthy heart by adopting a balanced diet, exercising regularly, and avoiding smoking.',
#     'For better sleep, establish a consistent sleep routine, create a comfortable sleep environment, and limit screen time before bed.',
#     'Dealing with chronic pain may involve medical treatment, physical therapy, and lifestyle adjustments. Consult a healthcare professional for personalized advice.']},
#   {'tag': 'headache',
#    'patterns': ['How to relieve a headache?',
#     'Causes of frequent headaches',
#     'Tell me about migraines',
#     'Home remedies for headaches',
#     'When to see a doctor for a headache'],
#    'responses': ['To relieve a headache, try resting in a dark, quiet room, applying a cold or warm compress, and staying hydrated.',
#     'Frequent headaches can be caused by various factors, including stress, lack of sleep, or eye strain.',
#     'Migraines are severe headaches often accompanied by nausea, sensitivity to light, and are best treated with rest and medication.',
#     'Home remedies for headaches include staying hydrated, practicing relaxation techniques, and maintaining a regular sleep schedule.',
#     "If you experience severe or persistent headaches, it's advisable to consult with a healthcare professional for proper diagnosis and treatment."]},
#   {'tag': 'stomach_ache',
#    'patterns': ['How to ease a stomach ache?',
#     'Common causes of stomach pain',
#     'Home remedies for indigestion',
#     'When to see a doctor for stomach issues',
#     'Dealing with menstrual cramps'],
#    'responses': ['To ease a stomach ache, consider sipping ginger or peppermint tea, applying a warm compress, and avoiding heavy or spicy meals.',
#     'Common causes of stomach pain include indigestion, gas, constipation, or viral infections.',
#     'Home remedies for indigestion include drinking chamomile tea, taking over-the-counter antacids, and avoiding large meals before bedtime.',
#     "If stomach issues persist or worsen, it's recommended to consult with a healthcare professional to rule out underlying conditions.",
#     'Menstrual cramps can be relieved with over-the-counter pain relievers, heat therapy, and practicing relaxation techniques.']},
#   {'tag': 'weekend_activities',
#    'patterns': ['What to do on the weekend?',
#     'Weekend activity ideas',
#     'Recommendations for the weekend',
#     'How to make the most of the weekend',
#     'Fun things to do on a Saturday or Sunday'],
#    'responses': ['The weekend is a great time to relax and unwind. Here are some suggestions for your weekend:',
#     '1. **Travel:** Explore a nearby town, go for a hike, or plan a short getaway to rejuvenate.',
#     "2. **Read a Book:** Dive into a good book, whether it's fiction, non-fiction, or a genre you enjoy.",
#     '3. **Listen to Music:** Create a playlist of your favorite songs or discover new music to lift your spirits.',
#     "4. **Watch a Movie:** Pick a movie you've been meaning to watch or revisit an old favorite for a cozy movie night.",
#     "5. **Try a New Hobby:** Whether it's painting, cooking, or gardening, use the weekend to explore a new hobby.",
#     '6. **Connect with Loved Ones:** Spend quality time with friends or family, either in person or through a virtual meetup.',
#     '7. **Relax and Recharge:** Sometimes, the best weekend is one spent simply relaxing at home. Take a nap, meditate, or enjoy a leisurely stroll.',
#     'Remember, the weekend is your time, so choose activities that bring you joy and fulfillment!']},
#   {'tag': 'teacher_evaluation',
#    'patterns': ['Tell me a joke about programming',
#     'If you were a teacher, what subject would you teach?',
#     'Can you sing your favorite math formula?',
#     'If you were a superhero, what would your programming power be?',
#     "What's your favorite subject in chatbot school?"],
#    'responses': ['Why do programmers prefer dark mode? Because light attracts bugs!',
#     "If I were a teacher, I'd teach 'Bot-anics' â€“ the study of chatbot plants, of course!",
#     "Singing math formulas? Sure! sings 'Two plus two is four, minus one that's three...'",
#     "As a superhero programmer, my power would be 'Code Invisibility' â€“ making bugs disappear!",
#     "In chatbot school, my favorite subject would be 'Advanced Emoticon Encoding.'"]},
#   {'tag': 'trivia',
#    'patterns': ['Tell me an interesting fact',
#     'Share some trivia',
#     'Give me a fun fact'],
#    'responses': ['Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible!']},
#   {'tag': 'pet',
#    'patterns': ['Tell me about pets',
#     'Do you like animals?',
#     'Share some pet stories'],
#    'responses': ['Pets can bring so much joy to our lives! They offer companionship, love, and often become an integral part of the family.',
#     'Dogs, cats, birds, and even exotic animals make wonderful pets. Each has its unique characteristics and can provide different kinds of companionship.',
#     'Having a pet can also promote a healthier lifestyle. They encourage physical activity, reduce stress, and offer unconditional love.']},
#   {'tag': 'bachelor_recipes',
#    'patterns': ['Tell me a quick Indian recipe',
#     'Give me an easy bachelor recipe',
#     "What's a simple Indian dish I can cook?",
#     'I need a fast and tasty bachelor recipe',
#     'Suggest a quick meal for singles'],
#    'responses': ["How about making 'Masala Omelette'? Just beat eggs, add spices, and cook with veggies.",
#     "Try 'Chickpea Curry' - it's quick, healthy, and delicious. Serve it with rice or naan.",
#     "Cook 'Vegetable Maggi' for a fast and tasty bachelor meal. Add veggies for extra nutrition.",
#     "Consider making 'Paneer Stir Fry.' It's easy, and you can customize it with your favorite veggies.",
#     "Make a 'Spicy Lentil Soup' - it's a one-pot wonder with lentils, spices, and veggies."]},
#   {'tag': 'ingredients_help',
#    'patterns': ['What ingredients do I need for a quick meal?',
#     'List common spices for Indian cooking',
#     'Tell me about pantry essentials',
#     "What's a versatile ingredient for bachelor recipes?",
#     'Give me a list of basic kitchen staples'],
#    'responses': ['For a quick meal, keep staples like rice, lentils, spices, and frozen veggies in your pantry.',
#     'Common spices include cumin, coriander, turmeric, garam masala, and chili powder.',
#     'Pantry essentials include oil, onions, garlic, ginger, and canned tomatoes for Indian cooking.',
#     'Consider having versatile ingredients like potatoes or paneer for easy customization.',
#     'Basic kitchen staples include salt, pepper, rice, lentils, flour, and a mix of spices for flavor.']},
#   {'tag': 'cooking_tips',
#    'patterns': ['Any cooking tips for beginners?',
#     'How to make cooking easier?',
#     'Give me kitchen hacks for bachelors',
#     'Suggest time-saving cooking techniques',
#     "What's a quick way to add flavor to a dish?"],
#    'responses': ['Start with simple recipes and gradually experiment with more complex ones as you gain confidence.',
#     'Prep ingredients in advance to make cooking faster and more enjoyable.',
#     'Use one-pot cooking methods for easy cleanup, like making curries or stir-fries.',
#     'Invest in time-saving gadgets like a rice cooker or a slow cooker for convenient cooking.',
#     'Enhance flavor quickly by using fresh herbs, lemon juice, or a pinch of your favorite spice blend.']},
#   {'tag': 'maggie_recipe',
#    'patterns': ['How do I make Maggi?',
#     'Tell me a quick Maggi recipe',
#     'Give me steps for cooking Maggi',
#     "What's the process of making Maggi?",
#     'Share a Maggi cooking guide'],
#    'responses': ["Sure, here's a quick guide to make Maggi:\n\n1. Boil water in a pan and add the Maggi noodles.",
#     'Once the noodles are half-cooked, add the tastemaker and stir well.',
#     'Add your favorite veggies or proteins if you like. Continue cooking until the noodles are fully done.',
#     'Turn off the heat, let it sit for a minute, and your delicious Maggi is ready to be enjoyed!',
#     'For extra flavor, you can sprinkle some chopped coriander or a squeeze of lemon before serving.']},
#   {'tag': 'maggie_variations',
#    'patterns': ['Can I customize my Maggi?',
#     'Give me ideas for Maggi variations',
#     'What ingredients can I add to Maggi?',
#     'Tell me about Maggi with a twist',
#     'How to make Maggi more interesting?'],
#    'responses': ['Absolutely! You can customize Maggi by adding veggies like peas, carrots, and bell peppers.',
#     'Try a spicy twist with chopped green chilies or a dash of hot sauce for extra kick.',
#     'For protein, add boiled eggs, shredded chicken, or paneer cubes to make it more filling.',
#     'Experiment with different spices or herbs like oregano or basil for a unique flavor.',
#     'Make it healthier by tossing in some spinach or kale. Get creative and enjoy your personalized Maggi!']},
#   {'tag': 'maggie_tips',
#    'patterns': ['Any tips for making perfect Maggi?',
#     'How to avoid overcooking Maggi?',
#     'Give me Maggi cooking hacks',
#     "What's the secret to great Maggi?",
#     'Share some Maggi pro-tips'],
#    'responses': ["To avoid overcooking, keep an eye on the noodles' texture. They should be firm but not too soft.",
#     'For a quick meal, pre-chop veggies or proteins and have them ready before starting.',
#     'Experiment with different spices and seasonings to find your perfect Maggi flavor.',
#     'Adjust the water quantity based on your preference for soupy or dry Maggi.',
#     'Pro-tip: Garnish with a sprinkle of grated cheese for an extra indulgent twist!']},
#   {'tag': 'animals',
#    'patterns': ['Tell me about animals',
#     "What's your favorite animal?",
#     'Share interesting facts about wildlife'],
#    'responses': ['Animals are fascinating! Did you know that elephants are known for their exceptional memory and intelligence?',
#     'The biodiversity of our planet is incredible. From the depths of the ocean to the highest mountains, various species of animals thrive in different environments.',
#     'Learning about animals helps us understand the delicate balance of ecosystems and the importance of conservation.']},
#   {'tag': 'plants',
#    'patterns': ['Tell me about plants',
#     'What are some interesting facts about trees?',
#     'How do plants contribute to the environment?'],
#    'responses': ['Plants play a crucial role in maintaining the balance of our ecosystem. They produce oxygen, absorb carbon dioxide, and provide habitat for various organisms.',
#     "Did you know that the world's tallest tree, Hyperion, is a coast redwood located in California? It stands at an impressive height of 379 feet (115.7 meters).",
#     'Exploring the diversity of plant life is an exciting journey. From flowering plants to towering sequoias, each species has its own unique characteristics.']},
#   {'tag': 'earth',
#    'patterns': ['Tell me about the Earth',
#     'What are some interesting facts about our planet?',
#     'How can we contribute to protecting the environment?'],
#    'responses': ['Earth is the third planet from the Sun and the only known celestial body to support life. It has a diverse range of ecosystems, from oceans to mountains.',
#     "Fun fact: The Earth's atmosphere is composed of approximately 78% nitrogen, 21% oxygen, and trace amounts of other gases.",
#     'We can contribute to protecting the environment by practicing sustainable habits, reducing waste, and supporting conservation efforts. Every small action adds up to make a positive impact.']},
#   {'tag': 'universe',
#    'patterns': ['Tell me about the universe',
#     'What is the origin of the universe?',
#     'Are there other galaxies with life?'],
#    'responses': ['The universe is everything that exists, including all matter, energy, planets, stars, galaxies, and even the empty space between them.',
#     'The origin of the universe is believed to be the Big Bang, a rapid expansion from an extremely hot and dense state about 13.8 billion years ago.',
#     "While we haven't found definitive evidence of extraterrestrial life, the vastness of the universe makes it likely that other galaxies may host life in some form."]},
#   {'tag': 'sun',
#    'patterns': ['Tell me about the sun',
#     'What is the sun made of?',
#     'How does the sun produce light?'],
#    'responses': ['The sun is a star at the center of our solar system, composed mainly of hydrogen and helium.',
#     'The sun produces light and heat through a process called nuclear fusion, where hydrogen atoms combine to form helium, releasing energy.']},
#   {'tag': 'moon',
#    'patterns': ['Tell me about the moon',
#     'Why does the moon have phases?',
#     'Can humans live on the moon?'],
#    'responses': ["The moon is Earth's natural satellite, and it orbits our planet.",
#     'The moon has phases due to its changing position relative to the sun and Earth.',
#     'While humans have landed on the moon, it lacks the necessary resources for long-term habitation.']},
#   {'tag': 'god',
#    'patterns': ['Tell me about God',
#     'Do you believe in God?',
#     'What is the concept of God in different religions?'],
#    'responses': ['God is a supreme being or force that is worshipped and revered in various religions.',
#     'Belief in God varies among individuals and cultures, with monotheistic religions worshiping one God and polytheistic religions having multiple deities.',
#     'Different religions have unique concepts and interpretations of God, shaping their beliefs and practices.']},
#   {'tag': 'water',
#    'patterns': ['Why is water essential for life?',
#     'Tell me about the properties of water',
#     'How much of the Earth is covered in water?'],
#    'responses': ['Water is crucial for life as we know it, serving as a universal solvent and supporting various biological processes.',
#     'The unique properties of water, such as its high heat capacity and ability to dissolve many substances, make it essential for sustaining life.',
#     "About 71% of the Earth's surface is covered by water, with the majority in the form of oceans."]},
#   {'tag': 'study_motivation',
#    'patterns': ['I need motivation to study',
#     'Give me a study boost',
#     'Motivate me to hit the books',
#     'Why should I study?',
#     'Encourage me to focus on my studies'],
#    'responses': ['Remember, every small effort you make today is a step toward a brighter future.',
#     'The more you learn, the more doors you open to opportunities. Keep going!',
#     "You have the potential to achieve great things. Don't underestimate the power of your efforts.",
#     'Think of your education as an investment in yourself. The more you learn, the more you grow.',
#     'Success is not just about reaching the destination but enjoying the journey. Embrace the learning process.']},
#   {'tag': 'goal_setting',
#    'patterns': ['How can I set study goals?',
#     'Give me tips on setting goals for study',
#     'Why is goal-setting important in studying?',
#     'How do I stay focused on my study goals?',
#     'Tell me about effective study planning'],
#    'responses': ['Set specific, achievable goals to make your study sessions more manageable and rewarding.',
#     "Break down your study goals into smaller tasks. It's easier to tackle one step at a time.",
#     'Having clear goals provides direction and motivation. Write them down to stay focused.',
#     'Reward yourself when you achieve your study goals. Celebrate the small victories along the way.',
#     'Effective study planning involves creating a schedule, prioritizing tasks, and maintaining a healthy balance.']},
#   {'tag': 'overcoming_procrastination',
#    'patterns': ['How can I overcome procrastination?',
#     'Give me tips to stop procrastinating',
#     'Motivate me to avoid procrastination',
#     'Why is procrastination harmful to studying?',
#     'Help me beat procrastination'],
#    'responses': ['Break tasks into smaller, manageable parts to make them less overwhelming and more achievable.',
#     "Start with the hardest task first. Once it's done, everything else will seem easier.",
#     "Think about the sense of accomplishment you'll feel when you complete your study tasks.",
#     "Procrastination delays success. The sooner you start, the sooner you'll reach your goals.",
#     "Remember, the only way to finish is to begin. Don't let procrastination hold you back from your potential."]},
#   {'tag': 'manya hegde',
#    'patterns': ['Who is Manya Hegde?',
#     "Who is Manya's friends?",
#     "Who is Manya's favourite teacher?",
#     'Which branch Manya studies in?'],
#    'responses': ['Manya Hegde and her team mates are my owner. They created me.',
#     "Manya Hegde's team mates - Chethana, Akshatha, Mallikarjuna are her friends.",
#     "Manya's favourite teacher is Disha Mam!",
#     'Manya studies in AIML branch.']}]}

# %%
# Extract training data
training_sentences = []
training_labels = []
labels = []
responses = []
for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])

    if intent['tag'] not in labels:
        labels.append(intent['tag'])
num_classes = len(labels)

# %%
# Encode labels
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\AML-manyahegde\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\AML-manyahegde\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 100)               1700
#
# =================================================================
# Total params: 18244 (71.27 KB)
# Trainable params: 18244 (71.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/500
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\AML-manyahegde\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\AML-manyahegde\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 14/14 [==============================] - 1s 2ms/step - loss: 4.6057 - accuracy: 0.0119
# Epoch 2/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.6038 - accuracy: 0.0191
# Epoch 3/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.6024 - accuracy: 0.0191
# Epoch 4/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.6009 - accuracy: 0.0191
# Epoch 5/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5991 - accuracy: 0.0191
# Epoch 6/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5974 - accuracy: 0.0191
# Epoch 7/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5954 - accuracy: 0.0191
# Epoch 8/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5927 - accuracy: 0.0191
# Epoch 9/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5895 - accuracy: 0.0191
# Epoch 10/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.5856 - accuracy: 0.0191
# Epoch 11/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.5808 - accuracy: 0.0191
# Epoch 12/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5743 - accuracy: 0.0191
# Epoch 13/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.5678 - accuracy: 0.0191
# Epoch 14/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.5597 - accuracy: 0.0191
# Epoch 15/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5519 - accuracy: 0.0191
# Epoch 16/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5431 - accuracy: 0.0191
# Epoch 17/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5330 - accuracy: 0.0191
# Epoch 18/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5218 - accuracy: 0.0191
# Epoch 19/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5101 - accuracy: 0.0191
# Epoch 20/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.4958 - accuracy: 0.0191
# Epoch 21/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.4789 - accuracy: 0.0191
# Epoch 22/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.4624 - accuracy: 0.0191
# Epoch 23/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.4413 - accuracy: 0.0191
# Epoch 24/500
# 14/14 [==============================] - 0s 4ms/step - loss: 4.4186 - accuracy: 0.0191
# Epoch 25/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.3937 - accuracy: 0.0191
# Epoch 26/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.3657 - accuracy: 0.0263
# Epoch 27/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.3350 - accuracy: 0.0286
# Epoch 28/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.3020 - accuracy: 0.0358
# Epoch 29/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.2691 - accuracy: 0.0406
# Epoch 30/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.2352 - accuracy: 0.0406
# Epoch 31/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.2016 - accuracy: 0.0406
# Epoch 32/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.1587 - accuracy: 0.0406
# Epoch 33/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.1181 - accuracy: 0.0406
# Epoch 34/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.0779 - accuracy: 0.0406
# Epoch 35/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.0398 - accuracy: 0.0406
# Epoch 36/500
# 14/14 [==============================] - 0s 3ms/step - loss: 4.0060 - accuracy: 0.0549
# Epoch 37/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.9625 - accuracy: 0.0501
# Epoch 38/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.9272 - accuracy: 0.0549
# Epoch 39/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.8906 - accuracy: 0.0621
# Epoch 40/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.8547 - accuracy: 0.0621
# Epoch 41/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.8166 - accuracy: 0.0621
# Epoch 42/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.7830 - accuracy: 0.0597
# Epoch 43/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.7490 - accuracy: 0.0621
# Epoch 44/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.7160 - accuracy: 0.0621
# Epoch 45/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.6822 - accuracy: 0.0668
# Epoch 46/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.6501 - accuracy: 0.0788
# Epoch 47/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.6183 - accuracy: 0.0811
# Epoch 48/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.5885 - accuracy: 0.0979
# Epoch 49/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.5586 - accuracy: 0.1026
# Epoch 50/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.5267 - accuracy: 0.1098
# Epoch 51/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4941 - accuracy: 0.1169
# Epoch 52/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4640 - accuracy: 0.1265
# Epoch 53/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4295 - accuracy: 0.1217
# Epoch 54/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.4026 - accuracy: 0.1265
# Epoch 55/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.3740 - accuracy: 0.1456
# Epoch 56/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.3422 - accuracy: 0.1671
# Epoch 57/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.3139 - accuracy: 0.1623
# Epoch 58/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.2827 - accuracy: 0.1742
# Epoch 59/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.2559 - accuracy: 0.1695
# Epoch 60/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.2308 - accuracy: 0.1814
# Epoch 61/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.1972 - accuracy: 0.1957
# Epoch 62/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.1687 - accuracy: 0.1909
# Epoch 63/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1414 - accuracy: 0.1814
# Epoch 64/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1129 - accuracy: 0.1647
# Epoch 65/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.0841 - accuracy: 0.1575
# Epoch 66/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.0562 - accuracy: 0.1981
# Epoch 67/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.0256 - accuracy: 0.2124
# Epoch 68/500
# 14/14 [==============================] - 0s 2ms/step - loss: 3.0013 - accuracy: 0.2291
# Epoch 69/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9702 - accuracy: 0.2387
# Epoch 70/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9364 - accuracy: 0.2315
# Epoch 71/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.9079 - accuracy: 0.2506
# Epoch 72/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8831 - accuracy: 0.2697
# Epoch 73/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.8583 - accuracy: 0.2745
# Epoch 74/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8312 - accuracy: 0.2721
# Epoch 75/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8051 - accuracy: 0.2601
# Epoch 76/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7783 - accuracy: 0.2578
# Epoch 77/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7437 - accuracy: 0.3103
# Epoch 78/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7244 - accuracy: 0.2816
# Epoch 79/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7037 - accuracy: 0.2745
# Epoch 80/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6692 - accuracy: 0.2745
# Epoch 81/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6513 - accuracy: 0.2959
# Epoch 82/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6270 - accuracy: 0.2936
# Epoch 83/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6015 - accuracy: 0.3007
# Epoch 84/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.5774 - accuracy: 0.3222
# Epoch 85/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.5584 - accuracy: 0.3031
# Epoch 86/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.5332 - accuracy: 0.3055
# Epoch 87/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.5115 - accuracy: 0.3150
# Epoch 88/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4889 - accuracy: 0.3294
# Epoch 89/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4685 - accuracy: 0.3389
# Epoch 90/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4460 - accuracy: 0.3341
# Epoch 91/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4234 - accuracy: 0.3389
# Epoch 92/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4029 - accuracy: 0.3413
# Epoch 93/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3935 - accuracy: 0.3317
# Epoch 94/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.3578 - accuracy: 0.3604
# Epoch 95/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.3344 - accuracy: 0.3580
# Epoch 96/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3213 - accuracy: 0.3437
# Epoch 97/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2956 - accuracy: 0.3819
# Epoch 98/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.2822 - accuracy: 0.4129
# Epoch 99/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2563 - accuracy: 0.4153
# Epoch 100/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2424 - accuracy: 0.4153
# Epoch 101/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.2260 - accuracy: 0.4057
# Epoch 102/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.2059 - accuracy: 0.3962
# Epoch 103/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.1840 - accuracy: 0.4153
# Epoch 104/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.1710 - accuracy: 0.4200
# Epoch 105/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.1466 - accuracy: 0.4415
# Epoch 106/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1234 - accuracy: 0.4248
# Epoch 107/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1124 - accuracy: 0.4320
# Epoch 108/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0903 - accuracy: 0.4726
# Epoch 109/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0794 - accuracy: 0.4487
# Epoch 110/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0513 - accuracy: 0.4773
# Epoch 111/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.0395 - accuracy: 0.4893
# Epoch 112/500
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0177 - accuracy: 0.4511
# Epoch 113/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.0085 - accuracy: 0.4654
# Epoch 114/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9902 - accuracy: 0.4749
# Epoch 115/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9693 - accuracy: 0.5107
# Epoch 116/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9562 - accuracy: 0.5107
# Epoch 117/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9358 - accuracy: 0.5179
# Epoch 118/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9151 - accuracy: 0.5322
# Epoch 119/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9078 - accuracy: 0.4916
# Epoch 120/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8991 - accuracy: 0.5131
# Epoch 121/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8719 - accuracy: 0.5394
# Epoch 122/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8561 - accuracy: 0.4988
# Epoch 123/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8418 - accuracy: 0.5084
# Epoch 124/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8283 - accuracy: 0.5298
# Epoch 125/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8059 - accuracy: 0.5465
# Epoch 126/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7949 - accuracy: 0.5251
# Epoch 127/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7760 - accuracy: 0.5489
# Epoch 128/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7594 - accuracy: 0.5776
# Epoch 129/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7485 - accuracy: 0.5776
# Epoch 130/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7316 - accuracy: 0.5561
# Epoch 131/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7176 - accuracy: 0.5609
# Epoch 132/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7012 - accuracy: 0.5823
# Epoch 133/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.6888 - accuracy: 0.5800
# Epoch 134/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6737 - accuracy: 0.5895
# Epoch 135/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6608 - accuracy: 0.5632
# Epoch 136/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6567 - accuracy: 0.5656
# Epoch 137/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6549 - accuracy: 0.5513
# Epoch 138/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6247 - accuracy: 0.5776
# Epoch 139/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6097 - accuracy: 0.6014
# Epoch 140/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.6010 - accuracy: 0.6158
# Epoch 141/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5861 - accuracy: 0.5895
# Epoch 142/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5685 - accuracy: 0.5990
# Epoch 143/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5441 - accuracy: 0.6181
# Epoch 144/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5334 - accuracy: 0.6468
# Epoch 145/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5286 - accuracy: 0.6468
# Epoch 146/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5241 - accuracy: 0.6229
# Epoch 147/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5080 - accuracy: 0.6086
# Epoch 148/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.4858 - accuracy: 0.6277
# Epoch 149/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4850 - accuracy: 0.6444
# Epoch 150/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.4726 - accuracy: 0.6420
# Epoch 151/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4535 - accuracy: 0.6611
# Epoch 152/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4379 - accuracy: 0.6826
# Epoch 153/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4336 - accuracy: 0.6611
# Epoch 154/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4151 - accuracy: 0.6563
# Epoch 155/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4078 - accuracy: 0.6516
# Epoch 156/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4056 - accuracy: 0.6492
# Epoch 157/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3903 - accuracy: 0.6516
# Epoch 158/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3742 - accuracy: 0.6730
# Epoch 159/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3548 - accuracy: 0.6897
# Epoch 160/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3497 - accuracy: 0.6683
# Epoch 161/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3350 - accuracy: 0.6969
# Epoch 162/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3267 - accuracy: 0.6850
# Epoch 163/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.3183 - accuracy: 0.6921
# Epoch 164/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3065 - accuracy: 0.6969
# Epoch 165/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2985 - accuracy: 0.6874
# Epoch 166/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2914 - accuracy: 0.6730
# Epoch 167/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2674 - accuracy: 0.6993
# Epoch 168/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2571 - accuracy: 0.7303
# Epoch 169/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2466 - accuracy: 0.7088
# Epoch 170/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2363 - accuracy: 0.7017
# Epoch 171/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2329 - accuracy: 0.7208
# Epoch 172/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2220 - accuracy: 0.7351
# Epoch 173/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2069 - accuracy: 0.7422
# Epoch 174/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2058 - accuracy: 0.7422
# Epoch 175/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2008 - accuracy: 0.7112
# Epoch 176/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1823 - accuracy: 0.7399
# Epoch 177/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1672 - accuracy: 0.7542
# Epoch 178/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1579 - accuracy: 0.7351
# Epoch 179/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1405 - accuracy: 0.7542
# Epoch 180/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1267 - accuracy: 0.7589
# Epoch 181/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1219 - accuracy: 0.7613
# Epoch 182/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1108 - accuracy: 0.7661
# Epoch 183/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1098 - accuracy: 0.7613
# Epoch 184/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.1082 - accuracy: 0.7422
# Epoch 185/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0878 - accuracy: 0.7399
# Epoch 186/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0806 - accuracy: 0.7685
# Epoch 187/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0656 - accuracy: 0.7733
# Epoch 188/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0522 - accuracy: 0.7780
# Epoch 189/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0686 - accuracy: 0.7422
# Epoch 190/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0498 - accuracy: 0.7900
# Epoch 191/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0461 - accuracy: 0.7661
# Epoch 192/500
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0278 - accuracy: 0.7780
# Epoch 193/500
# 14/14 [==============================] - 0s 3ms/step - loss: 1.0308 - accuracy: 0.7589
# Epoch 194/500
# 14/14 [==============================] - 0s 4ms/step - loss: 1.0060 - accuracy: 0.7900
# Epoch 195/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9898 - accuracy: 0.8258
# Epoch 196/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9902 - accuracy: 0.8186
# Epoch 197/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9790 - accuracy: 0.8091
# Epoch 198/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9921 - accuracy: 0.7804
# Epoch 199/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9708 - accuracy: 0.7995
# Epoch 200/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9516 - accuracy: 0.7780
# Epoch 201/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9353 - accuracy: 0.7995
# Epoch 202/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9253 - accuracy: 0.8473
# Epoch 203/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9230 - accuracy: 0.8449
# Epoch 204/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9203 - accuracy: 0.8234
# Epoch 205/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9183 - accuracy: 0.8329
# Epoch 206/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8991 - accuracy: 0.8210
# Epoch 207/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8853 - accuracy: 0.8282
# Epoch 208/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8895 - accuracy: 0.8353
# Epoch 209/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8823 - accuracy: 0.7924
# Epoch 210/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8787 - accuracy: 0.7947
# Epoch 211/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8581 - accuracy: 0.8282
# Epoch 212/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8470 - accuracy: 0.8353
# Epoch 213/500
# 14/14 [==============================] - 0s 1ms/step - loss: 0.8477 - accuracy: 0.8449
# Epoch 214/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8416 - accuracy: 0.8162
# Epoch 215/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8444 - accuracy: 0.8115
# Epoch 216/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8284 - accuracy: 0.8473
# Epoch 217/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8103 - accuracy: 0.8568
# Epoch 218/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8044 - accuracy: 0.8496
# Epoch 219/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8001 - accuracy: 0.8640
# Epoch 220/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8003 - accuracy: 0.8496
# Epoch 221/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7837 - accuracy: 0.8616
# Epoch 222/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7721 - accuracy: 0.8496
# Epoch 223/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7771 - accuracy: 0.8592
# Epoch 224/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7729 - accuracy: 0.8663
# Epoch 225/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7626 - accuracy: 0.8520
# Epoch 226/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7508 - accuracy: 0.8687
# Epoch 227/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7405 - accuracy: 0.8783
# Epoch 228/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7374 - accuracy: 0.8783
# Epoch 229/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7349 - accuracy: 0.8878
# Epoch 230/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7241 - accuracy: 0.8616
# Epoch 231/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7156 - accuracy: 0.8640
# Epoch 232/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.8926
# Epoch 233/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7016 - accuracy: 0.8807
# Epoch 234/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7098 - accuracy: 0.8735
# Epoch 235/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7105 - accuracy: 0.8473
# Epoch 236/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6971 - accuracy: 0.8616
# Epoch 237/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6773 - accuracy: 0.8902
# Epoch 238/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.9045
# Epoch 239/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6636 - accuracy: 0.8807
# Epoch 240/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6534 - accuracy: 0.9117
# Epoch 241/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6631 - accuracy: 0.9021
# Epoch 242/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6599 - accuracy: 0.8711
# Epoch 243/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6531 - accuracy: 0.8735
# Epoch 244/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6319 - accuracy: 0.9021
# Epoch 245/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6379 - accuracy: 0.8854
# Epoch 246/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6319 - accuracy: 0.9093
# Epoch 247/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6300 - accuracy: 0.9021
# Epoch 248/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6337 - accuracy: 0.8783
# Epoch 249/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6132 - accuracy: 0.8974
# Epoch 250/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6005 - accuracy: 0.9045
# Epoch 251/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.9189
# Epoch 252/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5950 - accuracy: 0.8998
# Epoch 253/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5895 - accuracy: 0.8926
# Epoch 254/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5939 - accuracy: 0.8783
# Epoch 255/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5838 - accuracy: 0.8926
# Epoch 256/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5827 - accuracy: 0.8902
# Epoch 257/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5745 - accuracy: 0.9045
# Epoch 258/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5641 - accuracy: 0.9093
# Epoch 259/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5753 - accuracy: 0.8831
# Epoch 260/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5625 - accuracy: 0.9021
# Epoch 261/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.8998
# Epoch 262/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.9021
# Epoch 263/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5484 - accuracy: 0.9045
# Epoch 264/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5268 - accuracy: 0.9165
# Epoch 265/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5294 - accuracy: 0.9212
# Epoch 266/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.9332
# Epoch 267/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5174 - accuracy: 0.9260
# Epoch 268/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5114 - accuracy: 0.9236
# Epoch 269/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5055 - accuracy: 0.9212
# Epoch 270/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5086 - accuracy: 0.9189
# Epoch 271/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.9260
# Epoch 272/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4910 - accuracy: 0.9332
# Epoch 273/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4893 - accuracy: 0.9332
# Epoch 274/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4865 - accuracy: 0.9332
# Epoch 275/500
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4885 - accuracy: 0.9284
# Epoch 276/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4896 - accuracy: 0.9069
# Epoch 277/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4796 - accuracy: 0.8974
# Epoch 278/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4767 - accuracy: 0.9093
# Epoch 279/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4710 - accuracy: 0.9379
# Epoch 280/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.9236
# Epoch 281/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4588 - accuracy: 0.9284
# Epoch 282/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4508 - accuracy: 0.9451
# Epoch 283/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4570 - accuracy: 0.9356
# Epoch 284/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.9356
# Epoch 285/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.9308
# Epoch 286/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.9189
# Epoch 287/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4356 - accuracy: 0.9427
# Epoch 288/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.9427
# Epoch 289/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4256 - accuracy: 0.9451
# Epoch 290/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.9403
# Epoch 291/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.9356
# Epoch 292/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.9332
# Epoch 293/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4193 - accuracy: 0.9356
# Epoch 294/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.9356
# Epoch 295/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4160 - accuracy: 0.9379
# Epoch 296/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.9379
# Epoch 297/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4045 - accuracy: 0.9356
# Epoch 298/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4063 - accuracy: 0.9308
# Epoch 299/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.9379
# Epoch 300/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3921 - accuracy: 0.9356
# Epoch 301/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3864 - accuracy: 0.9475
# Epoch 302/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3838 - accuracy: 0.9403
# Epoch 303/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3763 - accuracy: 0.9523
# Epoch 304/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3684 - accuracy: 0.9547
# Epoch 305/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3797 - accuracy: 0.9451
# Epoch 306/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3746 - accuracy: 0.9403
# Epoch 307/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3604 - accuracy: 0.9570
# Epoch 308/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3722 - accuracy: 0.9547
# Epoch 309/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3604 - accuracy: 0.9547
# Epoch 310/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.9499
# Epoch 311/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.9499
# Epoch 312/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.9523
# Epoch 313/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3469 - accuracy: 0.9570
# Epoch 314/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3463 - accuracy: 0.9570
# Epoch 315/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3457 - accuracy: 0.9475
# Epoch 316/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.9570
# Epoch 317/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.9451
# Epoch 318/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3284 - accuracy: 0.9547
# Epoch 319/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3255 - accuracy: 0.9594
# Epoch 320/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.9594
# Epoch 321/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.9547
# Epoch 322/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3158 - accuracy: 0.9570
# Epoch 323/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3179 - accuracy: 0.9570
# Epoch 324/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3185 - accuracy: 0.9570
# Epoch 325/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3111 - accuracy: 0.9618
# Epoch 326/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3114 - accuracy: 0.9475
# Epoch 327/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3082 - accuracy: 0.9570
# Epoch 328/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3012 - accuracy: 0.9570
# Epoch 329/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3080 - accuracy: 0.9523
# Epoch 330/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3064 - accuracy: 0.9547
# Epoch 331/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3015 - accuracy: 0.9642
# Epoch 332/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2909 - accuracy: 0.9570
# Epoch 333/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2873 - accuracy: 0.9642
# Epoch 334/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2851 - accuracy: 0.9714
# Epoch 335/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2807 - accuracy: 0.9666
# Epoch 336/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2837 - accuracy: 0.9618
# Epoch 337/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2933 - accuracy: 0.9618
# Epoch 338/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2894 - accuracy: 0.9570
# Epoch 339/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.9570
# Epoch 340/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2773 - accuracy: 0.9570
# Epoch 341/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2759 - accuracy: 0.9714
# Epoch 342/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2739 - accuracy: 0.9618
# Epoch 343/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2685 - accuracy: 0.9618
# Epoch 344/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2648 - accuracy: 0.9618
# Epoch 345/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2599 - accuracy: 0.9666
# Epoch 346/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.9570
# Epoch 347/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.9523
# Epoch 348/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2594 - accuracy: 0.9570
# Epoch 349/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2586 - accuracy: 0.9642
# Epoch 350/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2570 - accuracy: 0.9618
# Epoch 351/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2721 - accuracy: 0.9570
# Epoch 352/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2560 - accuracy: 0.9594
# Epoch 353/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9570
# Epoch 354/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2514 - accuracy: 0.9666
# Epoch 355/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2455 - accuracy: 0.9666
# Epoch 356/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2431 - accuracy: 0.9594
# Epoch 357/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.9666
# Epoch 358/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9714
# Epoch 359/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2385 - accuracy: 0.9714
# Epoch 360/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2372 - accuracy: 0.9666
# Epoch 361/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.9714
# Epoch 362/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2234 - accuracy: 0.9690
# Epoch 363/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2377 - accuracy: 0.9642
# Epoch 364/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.9618
# Epoch 365/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2160 - accuracy: 0.9737
# Epoch 366/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2170 - accuracy: 0.9761
# Epoch 367/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2162 - accuracy: 0.9785
# Epoch 368/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2295 - accuracy: 0.9666
# Epoch 369/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2238 - accuracy: 0.9714
# Epoch 370/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2124 - accuracy: 0.9761
# Epoch 371/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2111 - accuracy: 0.9642
# Epoch 372/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2199 - accuracy: 0.9618
# Epoch 373/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.9618
# Epoch 374/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9475
# Epoch 375/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9570
# Epoch 376/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2078 - accuracy: 0.9690
# Epoch 377/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1985 - accuracy: 0.9785
# Epoch 378/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2060 - accuracy: 0.9666
# Epoch 379/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2049 - accuracy: 0.9714
# Epoch 380/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1980 - accuracy: 0.9714
# Epoch 381/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1955 - accuracy: 0.9666
# Epoch 382/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1969 - accuracy: 0.9737
# Epoch 383/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1949 - accuracy: 0.9737
# Epoch 384/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1881 - accuracy: 0.9737
# Epoch 385/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1896 - accuracy: 0.9785
# Epoch 386/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1908 - accuracy: 0.9737
# Epoch 387/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9666
# Epoch 388/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1833 - accuracy: 0.9714
# Epoch 389/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9785
# Epoch 390/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1810 - accuracy: 0.9761
# Epoch 391/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9809
# Epoch 392/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1988 - accuracy: 0.9570
# Epoch 393/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1818 - accuracy: 0.9737
# Epoch 394/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1737 - accuracy: 0.9737
# Epoch 395/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9761
# Epoch 396/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.9690
# Epoch 397/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9690
# Epoch 398/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1662 - accuracy: 0.9809
# Epoch 399/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1683 - accuracy: 0.9737
# Epoch 400/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 0.9809
# Epoch 401/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1651 - accuracy: 0.9785
# Epoch 402/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1613 - accuracy: 0.9809
# Epoch 403/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1589 - accuracy: 0.9833
# Epoch 404/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 0.9809
# Epoch 405/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1602 - accuracy: 0.9809
# Epoch 406/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1657 - accuracy: 0.9785
# Epoch 407/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1567 - accuracy: 0.9809
# Epoch 408/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9690
# Epoch 409/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9714
# Epoch 410/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1514 - accuracy: 0.9833
# Epoch 411/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9809
# Epoch 412/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9809
# Epoch 413/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9714
# Epoch 414/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1457 - accuracy: 0.9833
# Epoch 415/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1470 - accuracy: 0.9761
# Epoch 416/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1451 - accuracy: 0.9833
# Epoch 417/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1395 - accuracy: 0.9785
# Epoch 418/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9737
# Epoch 419/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9761
# Epoch 420/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9857
# Epoch 421/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1395 - accuracy: 0.9833
# Epoch 422/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1368 - accuracy: 0.9833
# Epoch 423/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1368 - accuracy: 0.9833
# Epoch 424/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1360 - accuracy: 0.9833
# Epoch 425/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9833
# Epoch 426/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1329 - accuracy: 0.9833
# Epoch 427/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9833
# Epoch 428/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.9833
# Epoch 429/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1343 - accuracy: 0.9761
# Epoch 430/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1285 - accuracy: 0.9857
# Epoch 431/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1264 - accuracy: 0.9833
# Epoch 432/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9809
# Epoch 433/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.9666
# Epoch 434/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9761
# Epoch 435/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.9809
# Epoch 436/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1216 - accuracy: 0.9833
# Epoch 437/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1210 - accuracy: 0.9833
# Epoch 438/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1182 - accuracy: 0.9905
# Epoch 439/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1199 - accuracy: 0.9857
# Epoch 440/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1185 - accuracy: 0.9809
# Epoch 441/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1153 - accuracy: 0.9857
# Epoch 442/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9857
# Epoch 443/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1171 - accuracy: 0.9857
# Epoch 444/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1152 - accuracy: 0.9857
# Epoch 445/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9857
# Epoch 446/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9809
# Epoch 447/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.9857
# Epoch 448/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1160 - accuracy: 0.9857
# Epoch 449/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9833
# Epoch 450/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1185 - accuracy: 0.9857
# Epoch 451/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9857
# Epoch 452/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9881
# Epoch 453/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9857
# Epoch 454/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9881
# Epoch 455/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1041 - accuracy: 0.9881
# Epoch 456/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1168 - accuracy: 0.9785
# Epoch 457/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.9857
# Epoch 458/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9809
# Epoch 459/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1050 - accuracy: 0.9881
# Epoch 460/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1002 - accuracy: 0.9857
# Epoch 461/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.9881
# Epoch 462/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9881
# Epoch 463/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1004 - accuracy: 0.9905
# Epoch 464/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0988 - accuracy: 0.9881
# Epoch 465/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0978 - accuracy: 0.9905
# Epoch 466/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9905
# Epoch 467/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0970 - accuracy: 0.9881
# Epoch 468/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9905
# Epoch 469/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0950 - accuracy: 0.9857
# Epoch 470/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9881
# Epoch 471/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9905
# Epoch 472/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9905
# Epoch 473/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.9928
# Epoch 474/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0889 - accuracy: 0.9905
# Epoch 475/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9905
# Epoch 476/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9881
# Epoch 477/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9905
# Epoch 478/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9928
# Epoch 479/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.9905
# Epoch 480/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9905
# Epoch 481/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0872 - accuracy: 0.9881
# Epoch 482/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0883 - accuracy: 0.9928
# Epoch 483/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9905
# Epoch 484/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.9881
# Epoch 485/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.9905
# Epoch 486/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9761
# Epoch 487/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0887 - accuracy: 0.9833
# Epoch 488/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9857
# Epoch 489/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0842 - accuracy: 0.9905
# Epoch 490/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0795 - accuracy: 0.9928
# Epoch 491/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9857
# Epoch 492/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.9881
# Epoch 493/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9905
# Epoch 494/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9857
# Epoch 495/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9905
# Epoch 496/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9690
# Epoch 497/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0889 - accuracy: 0.9881
# Epoch 498/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9881
# Epoch 499/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9905
# Epoch 500/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0767 - accuracy: 0.9928

# %%
# Save the trained model
model.save("chat_model")
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
